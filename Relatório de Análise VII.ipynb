# %% [markdown]
# # **Relatório de Análise VII**

# %% [markdown]
# Neste sétimo relatório, vamos obter estatística descritivas de nossa base de dados. Esta tarefa será uma preparação para indentificarmos os dados discrepantes de nossa base para uma posterior remoção.

# %% [markdown]
# ## Estatística **Descritivas**

# %%
# Importa o pandas com o apelido pd
import pandas as pd

# Importa o CSV com os dados de imóveis residenciais
imoveis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Analise de Dados/Análise de Dados de imóveis/imoveis-residenciais (2).csv', sep=';')

# Exibe as cincos primeiras linhas do dataframe
imoveis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto Tipo Agregado
# 0  1700.0       500.0    60.0       2260.0   Apartamento
# 1  7000.0         0.0     0.0       7000.0          Casa
# 2  5200.0      4020.0  1111.0      10331.0   Apartamento
# 3   800.0       390.0    20.0       1210.0   Apartamento
# 4   800.0       230.0     0.0       1030.0   Apartamento

# %%
# Obtém o valor médio dos aluguéis
imoveis['Valor'].mean().round(2)
# Out:
# 13177.97

# %% [markdown]
# Para o conjunto de dados disponível, a média dos valores dos aluguéis de **R$13.177,97**. Desejamos, porém, obter o valor médio do aluguel para cada um dos tipos de imóveis. Para obter esta informação, precisamos fazer agrupamentos no dataframe:

# %%
imoveis.groupby('Tipo')['Valor'].mean().round(2)
# Out:
# Tipo
# Apartamento                      4805.30
# Box/Garagem                      1899.76
# Casa                             6793.45
# Casa Comercial                  14478.26
# Casa de Condomínio              11952.06
# Casa de Vila                     1574.37
# Chácara                          4900.00
# Conjunto Comercial/Sala         14715.05
# Flat                             4546.19
# Galpão/Depósito/Armazém         53407.06
# Hotel                           25000.00
# Indústria                      120000.00
# Loft                             2557.88
# Loja Shopping/ Ct Comercial      8126.18
# Loja/Salão                      13769.65
# Loteamento/Condomínio           22000.00
# Pousada/Chalé                    1480.00
# Prédio Inteiro                 498637.24
# Quitinete                        1246.84
# Studio                           2400.00
# Sítio                           12499.00
# Terreno Padrão                  32567.71
# Name: Valor, dtype: float64

# %%
# Obtém uma série com os bairros em que os imóveis estão localizados
imoveis['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2        Barra da Tijuca
# 3                 Centro
# 4           Higienópolis
#               ...
# 20554          Bancários
# 22613       Rio da Prata
# 22795      Cidade Jardim
# 24838    Parque Colúmbia
# 27683           Sepetiba
# Name: Bairro, Length: 161, dtype: object

# %%
# Lista com bairros de interesse
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Botafogo', 'Flamengo', 'Leblon', 'Tijuca']
bairros
# Out:
# ['Barra da Tijuca',
#  'Copacabana',
#  'Ipanema',
#  'Botafogo',
#  'Flamengo',
#  'Leblon',
#  'Tijuca']

# %%
# Filtro para selecionar somente os imóveis que estão na lista com os bairros de interesse
filtro = imoveis['Bairro'].isin(bairros)

#Filtra o dataframe
imoveis = imoveis[filtro]

# Exibe os bairros distintos da coluna 'Bairro'
imoveis['Bairro'].drop_duplicates()
# Out:
# 0           Copacabana
# 2      Barra da Tijuca
# 14            Botafogo
# 19              Tijuca
# 23              Leblon
# 25             Ipanema
# 107           Flamengo
# Name: Bairro, dtype: object

# %%
# Obtém o valor médio do aluguel para cada bairro
imoveis.groupby('Bairro')['Valor'].mean().round(2)
# Out:
# Bairro
# Barra da Tijuca     9035.20
# Botafogo           19709.72
# Copacabana          4514.54
# Flamengo            6923.50
# Ipanema            10455.03
# Leblon             11072.39
# Tijuca              2964.57
# Name: Valor, dtype: float64

# %%
# Obtém um conjunto de medidas acerca da variável aluguel
imoveis.groupby('Bairro')['Valor'].agg(['count','min','mean','median','max'])
# Out:
#                  count    min          mean  median        max
# Bairro
# Barra da Tijuca   6198  100.0   9035.204743  3500.0   738197.0
# Botafogo          1356  299.0  19709.716814  4000.0  4500000.0
# Copacabana        3070  100.0   4514.538436  3000.0   198000.0
# Flamengo           803  200.0   6923.498132  3000.0   212544.0
# Ipanema           2197  100.0  10455.031862  6900.0   800000.0
# Leblon            1459  100.0  11072.389308  7000.0   430000.0
# Tijuca            1346  320.0   2964.570579  1800.0   230000.0

# %%
# Obtém um resumo mais completo acerca dos valores da variável 'Valor'
imoveis.groupby('Bairro')['Valor'].describe().round(2)
# Out:
#                   count      mean        std    min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  6198.0   9035.20   30328.23  100.0  2000.0  3500.0   8000.0
# Botafogo         1356.0  19709.72  129879.42  299.0  2500.0  4000.0  11000.0
# Copacabana       3070.0   4514.54    6502.57  100.0  1900.0  3000.0   4900.0
# Flamengo          803.0   6923.50   15848.59  200.0  1900.0  3000.0   5300.0
# Ipanema          2197.0  10455.03   21002.14  100.0  4000.0  6900.0  12000.0
# Leblon           1459.0  11072.39   20830.80  100.0  4500.0  7000.0  11900.0
# Tijuca           1346.0   2964.57    8017.45  320.0  1400.0  1800.0   2500.0
#
#                        max
# Bairro
# Barra da Tijuca   738197.0
# Botafogo         4500000.0
# Copacabana        198000.0
# Flamengo          212544.0
# Ipanema           800000.0
# Leblon            430000.0
# Tijuca            230000.0

# %%
# Exporta o dataframe para análises posteriores
imoveis.to_csv('imoveis-residenciais.csv', sep=';', index=False)
