# %% [markdown]
# # **Relatório de Análise II**

# %% [markdown]
# Neste segundo relatório, nosso objetivo consiste em indentificar os tipos de imóveis distintos que estão na base de dados

# %% [markdown]
# # **Explorando os Tipos de Imóveis**

# %%
# Importa o pandas com o apelido pd
import pandas as pd

# Importa o módulo os
import os

# Lê o arquivo com os dados dos imóveis
imoveis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Analise de Dados/Análise de Dados de imóveis/aluguel.csv', sep=';')

# Exibe as cinco primeiras linhas do DataFrame
imoveis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# Exibe uma série com os tipos de imóveis
imoveis['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
# Armazena a série com os tipos de imóveis em uma variavel
tipos_de_imoveis = imoveis['Tipo']

# Exibe o tipo da variável
type(tipos_de_imoveis)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Suponhamos que queremos saber quais os tipos distintos de imóveis nesta base de dados:

# %%
# Remove os valores duplicados da série, mantendo somente a primeira ocorrência
tipos_de_imoveis.drop_duplicates()
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
# Remove os valores duplicados da série, mantendo somente a primeira ocorrência.
# Com o parâmetro 'inplace' definido com 'TRUE' modificaremos a série de forma permanente.
tipos_de_imoveis.drop_duplicates(inplace=True)

# Exibe a série
tipos_de_imoveis
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
# Exibe os índices da série  na forma de um array.
# Estes índices são os índices dos registros na base de dados.
tipos_de_imoveis.index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    16,    17,    29,    80,
#                83,   117,   159,   207,   347,   589,  2157,  3354,  4379,
#              4721,  6983,  9687, 23614],
#            dtype='int64')

# %% [markdown]
# Agora vamos redefinir estes índices para que eles sejam uma sequência de numeros inteiros:

# %%
# Exibe o número de registros da série 'tipos_de_imoveis'
len(tipos_de_imoveis)
# Out:
# 22

# %%
# Redefini o índice da série
tipos_de_imoveis.index = range(len(tipos_de_imoveis))

# Exibe a série
tipos_de_imoveis
# Out:
# 0                       Quitinete
# 1                            Casa
# 2         Conjunto Comercial/Sala
# 3                     Apartamento
# 4              Casa de Condomínio
# 5                  Prédio Inteiro
# 6                            Flat
# 7                      Loja/Salão
# 8         Galpão/Depósito/Armazém
# 9                  Casa Comercial
# 10                   Casa de Vila
# 11                 Terreno Padrão
# 12                    Box/Garagem
# 13                           Loft
# 14    Loja Shopping/ Ct Comercial
# 15                        Chácara
# 16          Loteamento/Condomínio
# 17                          Sítio
# 18                  Pousada/Chalé
# 19                         Studio
# 20                          Hotel
# 21                      Indústria
# Name: Tipo, dtype: object

# %%
# Transforma a série num dataframe
tipos_de_imoveis = tipos_de_imoveis.to_frame()
tipos_de_imoveis
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
# Renomeia o índice do DataFrame
tipos_de_imoveis.index.name = 'ID'

tipos_de_imoveis
# Out:
#                            Tipo
# ID
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria
