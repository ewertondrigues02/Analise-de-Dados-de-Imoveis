# %% [markdown]
# Importando Biblioteca

# %% [markdown]
# importando e nomeando bíblioteca do pandas como nome mais usado pela comunidade

# %%
import pandas as pd

# %% [markdown]
# Declarando a variavel **imoveis** recebendo os dados do arquivo **aluguel.csv**

# %%
imoveis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Analise de Dados/Análise de Dados de imóveis/aluguel.csv', sep=';')

# %% [markdown]
# Vendo as primeiras 5 colunas dos dados

# %%
imoveis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# Vendo a estrutura dos dados tipo, quantidade de colunas e linhas e sua quantidade

# %%
imoveis.info()

# Neste DataFrame tem 32960 linhas e 9 colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Exibe as informasções de base

linhas, colunas = imoveis.shape

# %%
# Exibe o resumo detalhado do DataFrame

print(f'A base de dados apresenta campos com {linhas} linhas e {colunas} colunas')
# Out:
# A base de dados apresenta campos com 32960 linhas e 9 colunas

# %%
# Exibe os tipos de Dados

imoveis.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
# Vamos Resetar os indices do dados

tipo_dos_campos = pd.DataFrame(data=imoveis.dtypes).reset_index()

# renomeia as colunas do DataFrame

tipo_dos_campos.columns = ['Campo', 'Tipo de Dados']

# Exibe o DataFrame

tipo_dos_campos
# Out:
#         Campo Tipo de Dados
# 0        Tipo        object
# 1      Bairro        object
# 2     Quartos         int64
# 3       Vagas         int64
# 4      Suites         int64
# 5        Area         int64
# 6       Valor       float64
# 7  Condominio       float64
# 8        IPTU       float64

# %%
# @title
