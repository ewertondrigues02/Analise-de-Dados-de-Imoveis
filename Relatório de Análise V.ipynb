# %% [markdown]
# # **Relatório de Análise V**

# %% [markdown]
# Neste quinto relatório nosso objetivo consistirá em tratar os valores faltantes de nossa  base de dados.

# %% [markdown]
# **Trantando Valores Faltantes**

# %%
# Importa o pandas com o apelido pd
import pandas as pd

# importa o CSV com os dados de imóveis do dataframe
imoveis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Analise de Dados/Análise de Dados de imóveis/aluguel.csv', sep=';')

# Exibe as cincos primeiras linhas do  dataframe
imoveis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# Cria uma série booleana
# Se o valor do aluguel estiver presente, retorna False
# Se o valor do aluguel não estiver presente, retorna True
imoveis['Valor'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Valor, Length: 32960, dtype: bool

# %%
# Obtém o número de imóveis sem o valor do aluguel
imoveis['Valor'].isnull().sum()
# Out:
# 17

# %%
# Seleciona todas os registros em que  o valor do alguel está faltando
imoveis[imoveis['Valor'].isnull()]
# Out:
#                               Tipo                   Bairro  Quartos  Vagas  \
# 76                     Apartamento          Barra da Tijuca        2      1
# 2186                   Apartamento                     Leme        2      0
# 2456                          Casa             Campo Grande        3      4
# 2646                    Loja/Salão          Barra da Tijuca        0      2
# 2941                   Apartamento                 Botafogo        2      0
# 2973                   Apartamento               Copacabana        2      0
# 6598                    Loja/Salão                  Andaraí        0      0
# 7302                          Casa             Campo Grande        3      2
# 12683                  Apartamento                     Leme        2      0
# 13229                  Apartamento                   Glória        3      0
# 13525                  Apartamento                    Gávea        3      1
# ...

# %%
# Obtém um resumo do dataframe
imoveis['Valor'].isnull().sum()
# Out:
# 17

# %% [markdown]
# Com este resumo, notamos que a coluna de valor do aluguel possui 17 registros nulos.

# %%
# Armazena o número de linhas do dataframe
a = imoveis.shape[0]

# Remove as linhas em que há valores nulos na coluna valor
imoveis.dropna(subset=['Valor'], inplace=True)

# Armazena o número de linhas do dataframe após a remoção de registros nulos
b = imoveis.shape[0]

# Exibe o número de linhas eliminadas
a - b
# Out:
# 17

# %% [markdown]
# Os imóveis classificados como 'Apartamento' devem obrigatóriamente possuir o valor de seu condomínio informado. Portanto, vamos remover todos os apartamentos em que o condomínio não foi informado:

# %%
# Filtro para selecionar os apartamentos com os valores de condomínio nulos
filtro = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())

# %%
# Número de imóveis antes de eliminar regsitros
a = imoveis.shape[0]

# seleciona todos os imóveis que não são do tipo apartamento ou os apartamentos que possuem valor de condomínio informado
imoveis = imoveis[~filtro]

# Número de imoveis depois de eliminar registros
b = imoveis.shape[0]

# Número de registros eliminados
a - b
# Out:
# 745

# %%
# Exibe o número de imóveis cujo condomínio é nulo
imoveis[imoveis['Condominio'].isnull()].shape[0]
# Out:
# 3344

# %% [markdown]
# Para estes imóveis com condomínio nulo, vamos atribuir o valor 0 já que de fato não possuem condomínio:

# %%
imoveis = imoveis.fillna({'Condominio': 0, 'IPTU': 0})

# %%
# imoveis['Condomini'].fillna(0, inplace = True)
# imoveis['IPTU'].fillna(0, inplace=True)

# %%
# Número de imóveis com condomínio nulo
imoveis[imoveis['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
# Número de imóveis com IPTU nulo
imoveis[imoveis['IPTU'].isnull()].shape[0]
# Out:
# 0

# %%
imoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32198 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32198 non-null  object
#  1   Bairro      32198 non-null  object
#  2   Quartos     32198 non-null  int64
#  3   Vagas       32198 non-null  int64
#  4   Suites      32198 non-null  int64
#  5   Area        32198 non-null  int64
#  6   Valor       32198 non-null  float64
#  7   Condominio  32198 non-null  float64
#  8   IPTU        32198 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.5+ MB

# %%
imoveis.to_csv('imoveis-resienciais.csv',sep=';', index=False)
